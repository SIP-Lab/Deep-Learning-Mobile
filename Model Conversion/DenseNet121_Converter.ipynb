# %% [markdown]
# ## Load all the Python Libraries Required

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input
from keras.applications.densenet import DenseNet121
import keras.backend as K
from tensorflow.python.framework import graph_util, graph_io
import coremltools
# Out:
# Using TensorFlow backend.
# WARNING:root:TensorFlow version 1.12.0 detected. Last version known to be fully compatible is 1.5.0 .

# %% [markdown]
# ### Set the learning phase using the backend as False and load the model

# %%
K.set_learning_phase(False)

# Load the model with the weights trained on Imagenet 
model = DenseNet121(weights='imagenet',include_top=True)
# Out:
# A local file was found, but it seems to be incomplete or outdated because the auto file hash does not match the original value of 0962ca643bae20f9b6771cb844dca3b0 so we will re-download the data.
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.8/densenet121_weights_tf_dim_ordering_tf_kernels.h5
# 34119680/34115984 [==============================] - 3s 0us/step

# %% [markdown]
# ### Convert the model into a coreml model

# %%
# Convert the loaded Keras model into a CoreML Model
# Provide image_input_names to specify it is an image model
# also provide the bias values specified by the model
mlmodel = coremltools.converters.keras.convert(model, 
                                               input_names=['image'], 
                                               image_input_names=['image'],
                                               output_names=['classLabelProbs', 'classLabel'],
                                               class_labels='labels.txt', 
                                               blue_bias=(-103.939 * 0.017), 
                                               green_bias=(-116.779 * 0.017), 
                                               red_bias=(-123.68 * 0.017), 
                                               image_scale=0.017)
# Out:
# Output name length mismatch
# 0 : input_1, <keras.engine.topology.InputLayer object at 0x1104f01d0>
# 1 : zero_padding2d_1, <keras.layers.convolutional.ZeroPadding2D object at 0xd2df68cc0>
# 2 : conv1/conv, <keras.layers.convolutional.Conv2D object at 0xd2df68a90>
# 3 : conv1/bn, <keras.layers.normalization.BatchNormalization object at 0xd2df68eb8>
# 4 : conv1/relu, <keras.layers.core.Activation object at 0xd2df68f28>
# 5 : zero_padding2d_2, <keras.layers.convolutional.ZeroPadding2D object at 0xd2df90048>
# 6 : pool1, <keras.layers.pooling.MaxPooling2D object at 0xd2df90da0>
# 7 : conv2_block1_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd2e04be10>
# 8 : conv2_block1_0_relu, <keras.layers.core.Activation object at 0xd2e0337b8>
# 9 : conv2_block1_1_conv, <keras.layers.convolutional.Conv2D object at 0xd2e092f98>
# 10 : conv2_block1_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd2e0926d8>
# 11 : conv2_block1_1_relu, <keras.layers.core.Activation object at 0xd2e118da0>
# 12 : conv2_block1_2_conv, <keras.layers.convolutional.Conv2D object at 0xd2e1ab780>
# 13 : conv2_block1_concat, <keras.layers.merge.Concatenate object at 0xd2e1ab668>
# 14 : conv2_block2_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd2e1fbe10>
# 15 : conv2_block2_0_relu, <keras.layers.core.Activation object at 0xd2e22ea20>
# 16 : conv2_block2_1_conv, <keras.layers.convolutional.Conv2D object at 0xd2e2d4470>
# 17 : conv2_block2_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd2e2d4b70>
# 18 : conv2_block2_1_relu, <keras.layers.core.Activation object at 0xd2e348358>
# 19 : conv2_block2_2_conv, <keras.layers.convolutional.Conv2D object at 0xd2e3e7550>
# 20 : conv2_block2_concat, <keras.layers.merge.Concatenate object at 0xd2e3e7438>
# 21 : conv2_block3_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd2e45a1d0>
# 22 : conv2_block3_0_relu, <keras.layers.core.Activation object at 0xd2e47cef0>
# 23 : conv2_block3_1_conv, <keras.layers.convolutional.Conv2D object at 0xd2e4befd0>
# 24 : conv2_block3_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd2e4ffb38>
# 25 : conv2_block3_1_relu, <keras.layers.core.Activation object at 0xd2e5711d0>
# 26 : conv2_block3_2_conv, <keras.layers.convolutional.Conv2D object at 0xd2e617518>
# 27 : conv2_block3_concat, <keras.layers.merge.Concatenate object at 0xd2e5d2f28>
# 28 : conv2_block4_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd2e68d828>
# 29 : conv2_block4_0_relu, <keras.layers.core.Activation object at 0xd2e656cc0>
# 30 : conv2_block4_1_conv, <keras.layers.convolutional.Conv2D object at 0xd2e6ece10>
# 31 : conv2_block4_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd2e72c978>
# 32 : conv2_block4_1_relu, <keras.layers.core.Activation object at 0xd2e7a3828>
# 33 : conv2_block4_2_conv, <keras.layers.convolutional.Conv2D object at 0xd2e841358>
# 34 : conv2_block4_concat, <keras.layers.merge.Concatenate object at 0xd2e7ffd68>
# 35 : conv2_block5_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd2e8fc198>
# 36 : conv2_block5_0_relu, <keras.layers.core.Activation object at 0xd2e881f98>
# 37 : conv2_block5_1_conv, <keras.layers.convolutional.Conv2D object at 0xd2e9547b8>
# 38 : conv2_block5_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd2e916ba8>
# 39 : conv2_block5_1_relu, <keras.layers.core.Activation object at 0xd2e9ca550>
# 40 : conv2_block5_2_conv, <keras.layers.convolutional.Conv2D object at 0xd2ea6ce10>
# 41 : conv2_block5_concat, <keras.layers.merge.Concatenate object at 0xd2ea2fe80>
# 42 : conv2_block6_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd2eade400>
# 43 : conv2_block6_0_relu, <keras.layers.core.Activation object at 0xd2ea88f98>
# 44 : conv2_block6_1_conv, <keras.layers.convolutional.Conv2D object at 0xd2eb81da0>
# 45 : conv2_block6_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd2eb40eb8>
# 46 : conv2_block6_1_relu, <keras.layers.core.Activation object at 0xd2ebf2470>
# 47 : conv2_block6_2_conv, <keras.layers.convolutional.Conv2D object at 0xd2ecb3d68>
# 48 : conv2_block6_concat, <keras.layers.merge.Concatenate object at 0xd2ec55ef0>
# 49 : pool2_bn, <keras.layers.normalization.BatchNormalization object at 0xd2ed112b0>
# 50 : pool2_relu, <keras.layers.core.Activation object at 0xd2ece15c0>
# 51 : pool2_conv, <keras.layers.convolutional.Conv2D object at 0xd2ed78748>
# 52 : pool2_pool, <keras.layers.pooling.AveragePooling2D object at 0xd2ed78c50>
# 53 : conv3_block1_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd2edf66a0>
# 54 : conv3_block1_0_relu, <keras.layers.core.Activation object at 0xd2ee242e8>
# 55 : conv3_block1_1_conv, <keras.layers.convolutional.Conv2D object at 0xd2ee8a780>
# 56 : conv3_block1_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd2eebd518>
# 57 : conv3_block1_1_relu, <keras.layers.core.Activation object at 0xd2ef2d470>
# 58 : conv3_block1_2_conv, <keras.layers.convolutional.Conv2D object at 0xd2efeed68>
# 59 : conv3_block1_concat, <keras.layers.merge.Concatenate object at 0xd2ef91ef0>
# 60 : conv3_block2_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd2f04b2b0>
# 61 : conv3_block2_0_relu, <keras.layers.core.Activation object at 0xd2f01a5c0>
# 62 : conv3_block2_1_conv, <keras.layers.convolutional.Conv2D object at 0xd2f0b4748>
# 63 : conv3_block2_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd2f0b4c50>
# 64 : conv3_block2_1_relu, <keras.layers.core.Activation object at 0xd2f1602b0>
# 65 : conv3_block2_2_conv, <keras.layers.convolutional.Conv2D object at 0xd2f219e10>
# 66 : conv3_block2_concat, <keras.layers.merge.Concatenate object at 0xd2f1c9d30>
# 67 : conv3_block3_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd2f2760f0>
# 68 : conv3_block3_0_relu, <keras.layers.core.Activation object at 0xd2f242400>
# 69 : conv3_block3_1_conv, <keras.layers.convolutional.Conv2D object at 0xd2f332e10>
# 70 : conv3_block3_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd2f2ddb70>
# 71 : conv3_block3_1_relu, <keras.layers.core.Activation object at 0xd2f38c0f0>
# 72 : conv3_block3_2_conv, <keras.layers.convolutional.Conv2D object at 0xd2f406a90>
# 73 : conv3_block3_concat, <keras.layers.merge.Concatenate object at 0xd2f406978>
# 74 : conv3_block4_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd2f483780>
# 75 : conv3_block4_0_relu, <keras.layers.core.Activation object at 0xd2f483dd8>
# 76 : conv3_block4_1_conv, <keras.layers.convolutional.Conv2D object at 0xd2f51a7b8>
# 77 : conv3_block4_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd2f51ae10>
# 78 : conv3_block4_1_relu, <keras.layers.core.Activation object at 0xd2f59af28>
# 79 : conv3_block4_2_conv, <keras.layers.convolutional.Conv2D object at 0xd2f631908>
# 80 : conv3_block4_concat, <keras.layers.merge.Concatenate object at 0xd2f6317f0>
# 81 : conv3_block5_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd2f6da080>
# 82 : conv3_block5_0_relu, <keras.layers.core.Activation object at 0xd2f6b0a58>
# 83 : conv3_block5_1_conv, <keras.layers.convolutional.Conv2D object at 0xd2f745630>
# 84 : conv3_block5_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd2f745e80>
# 85 : conv3_block5_1_relu, <keras.layers.core.Activation object at 0xd2f7c2cf8>
# 86 : conv3_block5_2_conv, <keras.layers.convolutional.Conv2D object at 0xd2f85b6a0>
# 87 : conv3_block5_concat, <keras.layers.merge.Concatenate object at 0xd2f85b588>
# 88 : conv3_block6_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd2f8aef98>
# 89 : conv3_block6_0_relu, <keras.layers.core.Activation object at 0xd2f8dd9b0>
# 90 : conv3_block6_1_conv, <keras.layers.convolutional.Conv2D object at 0xd2f97e5f8>
# 91 : conv3_block6_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd2f97e8d0>
# 92 : conv3_block6_1_relu, <keras.layers.core.Activation object at 0xd2f9f2358>
# 93 : conv3_block6_2_conv, <keras.layers.convolutional.Conv2D object at 0xd2fa97550>
# 94 : conv3_block6_concat, <keras.layers.merge.Concatenate object at 0xd2fa97438>
# 95 : conv3_block7_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd2fad7e48>
# 96 : conv3_block7_0_relu, <keras.layers.core.Activation object at 0xd2fb086a0>
# 97 : conv3_block7_1_conv, <keras.layers.convolutional.Conv2D object at 0xd2fb6af98>
# 98 : conv3_block7_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd2fbaeb00>
# 99 : conv3_block7_1_relu, <keras.layers.core.Activation object at 0xd2fc1f9b0>
# 100 : conv3_block7_2_conv, <keras.layers.convolutional.Conv2D object at 0xd2fcc44e0>
# 101 : conv3_block7_concat, <keras.layers.merge.Concatenate object at 0xd2fc81ef0>
# 102 : conv3_block8_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd2fd387f0>
# 103 : conv3_block8_0_relu, <keras.layers.core.Activation object at 0xd2fd03fd0>
# 104 : conv3_block8_1_conv, <keras.layers.convolutional.Conv2D object at 0xd2fd98dd8>
# 105 : conv3_block8_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd2fdd9940>
# 106 : conv3_block8_1_relu, <keras.layers.core.Activation object at 0xd2fe4f7f0>
# 107 : conv3_block8_2_conv, <keras.layers.convolutional.Conv2D object at 0xd2fef0320>
# 108 : conv3_block8_concat, <keras.layers.merge.Concatenate object at 0xd2feafd30>
# 109 : conv3_block9_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd2ffa7160>
# 110 : conv3_block9_0_relu, <keras.layers.core.Activation object at 0xd2ff2cf60>
# 111 : conv3_block9_1_conv, <keras.layers.convolutional.Conv2D object at 0xd2ffc2ac8>
# 112 : conv3_block9_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd2ffc2e10>
# 113 : conv3_block9_1_relu, <keras.layers.core.Activation object at 0xd3007a518>
# 114 : conv3_block9_2_conv, <keras.layers.convolutional.Conv2D object at 0xd30116dd8>
# 115 : conv3_block9_concat, <keras.layers.merge.Concatenate object at 0xd300d9e48>
# 116 : conv3_block10_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd3018a4a8>
# 117 : conv3_block10_0_relu, <keras.layers.core.Activation object at 0xd3015e7b8>
# 118 : conv3_block10_1_conv, <keras.layers.convolutional.Conv2D object at 0xd3022ddd8>
# 119 : conv3_block10_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd301f1f28>
# 120 : conv3_block10_1_relu, <keras.layers.core.Activation object at 0xd302a3438>
# 121 : conv3_block10_2_conv, <keras.layers.convolutional.Conv2D object at 0xd30363fd0>
# 122 : conv3_block10_concat, <keras.layers.merge.Concatenate object at 0xd30309eb8>
# 123 : conv3_block11_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd303c1278>
# 124 : conv3_block11_0_relu, <keras.layers.core.Activation object at 0xd30390588>
# 125 : conv3_block11_1_conv, <keras.layers.convolutional.Conv2D object at 0xd3042a710>
# 126 : conv3_block11_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd3042ac18>
# 127 : conv3_block11_1_relu, <keras.layers.core.Activation object at 0xd304d92b0>
# 128 : conv3_block11_2_conv, <keras.layers.convolutional.Conv2D object at 0xd3058ee10>
# 129 : conv3_block11_concat, <keras.layers.merge.Concatenate object at 0xd3053fcf8>
# 130 : conv3_block12_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd305ec0f0>
# 131 : conv3_block12_0_relu, <keras.layers.core.Activation object at 0xd305b9400>
# 132 : conv3_block12_1_conv, <keras.layers.convolutional.Conv2D object at 0xd306a7e10>
# 133 : conv3_block12_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd30652b70>
# 134 : conv3_block12_1_relu, <keras.layers.core.Activation object at 0xd307040f0>
# 135 : conv3_block12_2_conv, <keras.layers.convolutional.Conv2D object at 0xd30769a90>
# 136 : conv3_block12_concat, <keras.layers.merge.Concatenate object at 0xd30769978>
# 137 : pool3_bn, <keras.layers.normalization.BatchNormalization object at 0xd307ea780>
# 138 : pool3_relu, <keras.layers.core.Activation object at 0xd307eadd8>
# 139 : pool3_conv, <keras.layers.convolutional.Conv2D object at 0xd3087d7b8>
# 140 : pool3_pool, <keras.layers.pooling.AveragePooling2D object at 0xd3087de10>
# 141 : conv4_block1_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd308ffe80>
# 142 : conv4_block1_0_relu, <keras.layers.core.Activation object at 0xd308ffef0>
# 143 : conv4_block1_1_conv, <keras.layers.convolutional.Conv2D object at 0xd30993f28>
# 144 : conv4_block1_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd309933c8>
# 145 : conv4_block1_1_relu, <keras.layers.core.Activation object at 0xd30a3a198>
# 146 : conv4_block1_2_conv, <keras.layers.convolutional.Conv2D object at 0xd30aa79b0>
# 147 : conv4_block1_concat, <keras.layers.merge.Concatenate object at 0xd30aa7898>
# 148 : conv4_block2_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd30b50320>
# 149 : conv4_block2_0_relu, <keras.layers.core.Activation object at 0xd30b236d8>
# 150 : conv4_block2_1_conv, <keras.layers.convolutional.Conv2D object at 0xd30bba6d8>
# 151 : conv4_block2_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd30bbaba8>
# 152 : conv4_block2_1_relu, <keras.layers.core.Activation object at 0xd30c39f28>
# 153 : conv4_block2_2_conv, <keras.layers.convolutional.Conv2D object at 0xd30cd0828>
# 154 : conv4_block2_concat, <keras.layers.merge.Concatenate object at 0xd30cd0710>
# 155 : conv4_block3_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd30d22ef0>
# 156 : conv4_block3_0_relu, <keras.layers.core.Activation object at 0xd30d4c978>
# 157 : conv4_block3_1_conv, <keras.layers.convolutional.Conv2D object at 0xd30de3550>
# 158 : conv4_block3_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd30de3c50>
# 159 : conv4_block3_1_relu, <keras.layers.core.Activation object at 0xd30e6aac8>
# 160 : conv4_block3_2_conv, <keras.layers.convolutional.Conv2D object at 0xd30efb5f8>
# 161 : conv4_block3_concat, <keras.layers.merge.Concatenate object at 0xd30efb4e0>
# 162 : conv4_block4_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd30f80240>
# 163 : conv4_block4_0_relu, <keras.layers.core.Activation object at 0xd30fe0f98>
# 164 : conv4_block4_1_conv, <keras.layers.convolutional.Conv2D object at 0xd31024b38>
# 165 : conv4_block4_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd31024cf8>
# 166 : conv4_block4_1_relu, <keras.layers.core.Activation object at 0xd31090278>
# 167 : conv4_block4_2_conv, <keras.layers.convolutional.Conv2D object at 0xd310f7fd0>
# 168 : conv4_block4_concat, <keras.layers.merge.Concatenate object at 0xd31137358>
# 169 : conv4_block5_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd311a98d0>
# 170 : conv4_block5_0_relu, <keras.layers.core.Activation object at 0xd3117bf60>
# 171 : conv4_block5_1_conv, <keras.layers.convolutional.Conv2D object at 0xd31211eb8>
# 172 : conv4_block5_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd3124fa20>
# 173 : conv4_block5_1_relu, <keras.layers.core.Activation object at 0xd31351780>
# 174 : conv4_block5_2_conv, <keras.layers.convolutional.Conv2D object at 0xd313f7358>
# 175 : conv4_block5_concat, <keras.layers.merge.Concatenate object at 0xd313b6d68>
# 176 : conv4_block6_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd3146a710>
# 177 : conv4_block6_0_relu, <keras.layers.core.Activation object at 0xd31435f98>
# 178 : conv4_block6_1_conv, <keras.layers.convolutional.Conv2D object at 0xd314cbfd0>
# 179 : conv4_block6_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd3150c9b0>
# 180 : conv4_block6_1_relu, <keras.layers.core.Activation object at 0xd31581748>
# 181 : conv4_block6_2_conv, <keras.layers.convolutional.Conv2D object at 0xd315e3be0>
# 182 : conv4_block6_concat, <keras.layers.merge.Concatenate object at 0xd315e3f98>
# 183 : conv4_block7_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd316dc0b8>
# 184 : conv4_block7_0_relu, <keras.layers.core.Activation object at 0xd31668f60>
# 185 : conv4_block7_1_conv, <keras.layers.convolutional.Conv2D object at 0xd316f8a20>
# 186 : conv4_block7_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd316f8d68>
# 187 : conv4_block7_1_relu, <keras.layers.core.Activation object at 0xd317ac3c8>
# 188 : conv4_block7_2_conv, <keras.layers.convolutional.Conv2D object at 0xd3180dac8>
# 189 : conv4_block7_concat, <keras.layers.merge.Concatenate object at 0xd3180de80>
# 190 : conv4_block8_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd318be358>
# 191 : conv4_block8_0_relu, <keras.layers.core.Activation object at 0xd31897668>
# 192 : conv4_block8_1_conv, <keras.layers.convolutional.Conv2D object at 0xd3192e7f0>
# 193 : conv4_block8_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd3192ecf8>
# 194 : conv4_block8_1_relu, <keras.layers.core.Activation object at 0xd319d6390>
# 195 : conv4_block8_2_conv, <keras.layers.convolutional.Conv2D object at 0xd31a97e80>
# 196 : conv4_block8_concat, <keras.layers.merge.Concatenate object at 0xd31a44e10>
# 197 : conv4_block9_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd31af31d0>
# 198 : conv4_block9_0_relu, <keras.layers.core.Activation object at 0xd31abf4e0>
# 199 : conv4_block9_1_conv, <keras.layers.convolutional.Conv2D object at 0xd31b58668>
# 200 : conv4_block9_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd31b58b70>
# 201 : conv4_block9_1_relu, <keras.layers.core.Activation object at 0xd31c091d0>
# 202 : conv4_block9_2_conv, <keras.layers.convolutional.Conv2D object at 0xd31c71b70>
# 203 : conv4_block9_concat, <keras.layers.merge.Concatenate object at 0xd31c71a58>
# 204 : conv4_block10_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd31d1d198>
# 205 : conv4_block10_0_relu, <keras.layers.core.Activation object at 0xd31ce9dd8>
# 206 : conv4_block10_1_conv, <keras.layers.convolutional.Conv2D object at 0xd31d859b0>
# 207 : conv4_block10_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd31d85898>
# 208 : conv4_block10_1_relu, <keras.layers.core.Activation object at 0xd31e33198>
# 209 : conv4_block10_2_conv, <keras.layers.convolutional.Conv2D object at 0xd31e9a9b0>
# 210 : conv4_block10_concat, <keras.layers.merge.Concatenate object at 0xd31e9a898>
# 211 : conv4_block11_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd31f45320>
# 212 : conv4_block11_0_relu, <keras.layers.core.Activation object at 0xd31f1b6d8>
# 213 : conv4_block11_1_conv, <keras.layers.convolutional.Conv2D object at 0xd31fb06d8>
# 214 : conv4_block11_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd31fb0ba8>
# 215 : conv4_block11_1_relu, <keras.layers.core.Activation object at 0xd3202ef28>
# 216 : conv4_block11_2_conv, <keras.layers.convolutional.Conv2D object at 0xd320c8828>
# 217 : conv4_block11_concat, <keras.layers.merge.Concatenate object at 0xd320c8710>
# 218 : conv4_block12_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd3211aef0>
# 219 : conv4_block12_0_relu, <keras.layers.core.Activation object at 0xd32146978>
# 220 : conv4_block12_1_conv, <keras.layers.convolutional.Conv2D object at 0xd321dc550>
# 221 : conv4_block12_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd321dcc50>
# 222 : conv4_block12_1_relu, <keras.layers.core.Activation object at 0xd32261ac8>
# 223 : conv4_block12_2_conv, <keras.layers.convolutional.Conv2D object at 0xd322f25f8>
# 224 : conv4_block12_concat, <keras.layers.merge.Concatenate object at 0xd322f24e0>
# 225 : conv4_block13_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd32374240>
# 226 : conv4_block13_0_relu, <keras.layers.core.Activation object at 0xd323dbf98>
# 227 : conv4_block13_1_conv, <keras.layers.convolutional.Conv2D object at 0xd3241ab38>
# 228 : conv4_block13_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd3241acf8>
# 229 : conv4_block13_1_relu, <keras.layers.core.Activation object at 0xd32488278>
# 230 : conv4_block13_2_conv, <keras.layers.convolutional.Conv2D object at 0xd324f3fd0>
# 231 : conv4_block13_concat, <keras.layers.merge.Concatenate object at 0xd32531358>
# 232 : conv4_block14_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd325a28d0>
# 233 : conv4_block14_0_relu, <keras.layers.core.Activation object at 0xd32570f60>
# 234 : conv4_block14_1_conv, <keras.layers.convolutional.Conv2D object at 0xd32605eb8>
# 235 : conv4_block14_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd32646a20>
# 236 : conv4_block14_1_relu, <keras.layers.core.Activation object at 0xd326b78d0>
# 237 : conv4_block14_2_conv, <keras.layers.convolutional.Conv2D object at 0xd3275d400>
# 238 : conv4_block14_concat, <keras.layers.merge.Concatenate object at 0xd3271ce10>
# 239 : conv4_block15_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd327d1710>
# 240 : conv4_block15_0_relu, <keras.layers.core.Activation object at 0xd3279bf98>
# 241 : conv4_block15_1_conv, <keras.layers.convolutional.Conv2D object at 0xd32831fd0>
# 242 : conv4_block15_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd328739b0>
# 243 : conv4_block15_1_relu, <keras.layers.core.Activation object at 0xd328e7748>
# 244 : conv4_block15_2_conv, <keras.layers.convolutional.Conv2D object at 0xd32948be0>
# 245 : conv4_block15_concat, <keras.layers.merge.Concatenate object at 0xd32948f98>
# 246 : conv4_block16_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd32a410b8>
# 247 : conv4_block16_0_relu, <keras.layers.core.Activation object at 0xd329ccf60>
# 248 : conv4_block16_1_conv, <keras.layers.convolutional.Conv2D object at 0xd32a5ba20>
# 249 : conv4_block16_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd32a5bd68>
# 250 : conv4_block16_1_relu, <keras.layers.core.Activation object at 0xd32b103c8>
# 251 : conv4_block16_2_conv, <keras.layers.convolutional.Conv2D object at 0xd32b73ac8>
# 252 : conv4_block16_concat, <keras.layers.merge.Concatenate object at 0xd32b73e80>
# 253 : conv4_block17_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd32c25358>
# 254 : conv4_block17_0_relu, <keras.layers.core.Activation object at 0xd32bfe668>
# 255 : conv4_block17_1_conv, <keras.layers.convolutional.Conv2D object at 0xd32c967f0>
# 256 : conv4_block17_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd32c96cf8>
# 257 : conv4_block17_1_relu, <keras.layers.core.Activation object at 0xd32d3c390>
# 258 : conv4_block17_2_conv, <keras.layers.convolutional.Conv2D object at 0xd32dfee80>
# 259 : conv4_block17_concat, <keras.layers.merge.Concatenate object at 0xd32daae10>
# 260 : conv4_block18_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd32e5d1d0>
# 261 : conv4_block18_0_relu, <keras.layers.core.Activation object at 0xd32e264e0>
# 262 : conv4_block18_1_conv, <keras.layers.convolutional.Conv2D object at 0xd32ebf668>
# 263 : conv4_block18_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd32ebfb70>
# 264 : conv4_block18_1_relu, <keras.layers.core.Activation object at 0xd32f721d0>
# 265 : conv4_block18_2_conv, <keras.layers.convolutional.Conv2D object at 0xd32fd7b70>
# 266 : conv4_block18_concat, <keras.layers.merge.Concatenate object at 0xd32fd7a58>
# 267 : conv4_block19_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd33082198>
# 268 : conv4_block19_0_relu, <keras.layers.core.Activation object at 0xd33050dd8>
# 269 : conv4_block19_1_conv, <keras.layers.convolutional.Conv2D object at 0xd330ec9b0>
# 270 : conv4_block19_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd330ec898>
# 271 : conv4_block19_1_relu, <keras.layers.core.Activation object at 0xd3319a198>
# 272 : conv4_block19_2_conv, <keras.layers.convolutional.Conv2D object at 0xd332009b0>
# 273 : conv4_block19_concat, <keras.layers.merge.Concatenate object at 0xd33200898>
# 274 : conv4_block20_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd332ab320>
# 275 : conv4_block20_0_relu, <keras.layers.core.Activation object at 0xd3327f6d8>
# 276 : conv4_block20_1_conv, <keras.layers.convolutional.Conv2D object at 0xd333196d8>
# 277 : conv4_block20_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd33319ba8>
# 278 : conv4_block20_1_relu, <keras.layers.core.Activation object at 0xd33398f28>
# 279 : conv4_block20_2_conv, <keras.layers.convolutional.Conv2D object at 0xd3342e828>
# 280 : conv4_block20_concat, <keras.layers.merge.Concatenate object at 0xd3342e710>
# 281 : conv4_block21_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd33480ef0>
# 282 : conv4_block21_0_relu, <keras.layers.core.Activation object at 0xd334ac978>
# 283 : conv4_block21_1_conv, <keras.layers.convolutional.Conv2D object at 0xd33542550>
# 284 : conv4_block21_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd33542c50>
# 285 : conv4_block21_1_relu, <keras.layers.core.Activation object at 0xd335caac8>
# 286 : conv4_block21_2_conv, <keras.layers.convolutional.Conv2D object at 0xd336585f8>
# 287 : conv4_block21_concat, <keras.layers.merge.Concatenate object at 0xd336584e0>
# 288 : conv4_block22_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd336de240>
# 289 : conv4_block22_0_relu, <keras.layers.core.Activation object at 0xd33740f98>
# 290 : conv4_block22_1_conv, <keras.layers.convolutional.Conv2D object at 0xd33782b38>
# 291 : conv4_block22_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd33782cf8>
# 292 : conv4_block22_1_relu, <keras.layers.core.Activation object at 0xd337f2278>
# 293 : conv4_block22_2_conv, <keras.layers.convolutional.Conv2D object at 0xd33858fd0>
# 294 : conv4_block22_concat, <keras.layers.merge.Concatenate object at 0xd33896358>
# 295 : conv4_block23_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd339088d0>
# 296 : conv4_block23_0_relu, <keras.layers.core.Activation object at 0xd338d7f60>
# 297 : conv4_block23_1_conv, <keras.layers.convolutional.Conv2D object at 0xd3396deb8>
# 298 : conv4_block23_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd339aea20>
# 299 : conv4_block23_1_relu, <keras.layers.core.Activation object at 0xd33a1e8d0>
# 300 : conv4_block23_2_conv, <keras.layers.convolutional.Conv2D object at 0xd33ac6400>
# 301 : conv4_block23_concat, <keras.layers.merge.Concatenate object at 0xd33a82eb8>
# 302 : conv4_block24_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd33b05fd0>
# 303 : conv4_block24_0_relu, <keras.layers.core.Activation object at 0xd33b389e8>
# 304 : conv4_block24_1_conv, <keras.layers.convolutional.Conv2D object at 0xd33b9cf98>
# 305 : conv4_block24_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd33bda978>
# 306 : conv4_block24_1_relu, <keras.layers.core.Activation object at 0xd33c4d748>
# 307 : conv4_block24_2_conv, <keras.layers.convolutional.Conv2D object at 0xd33cb1be0>
# 308 : conv4_block24_concat, <keras.layers.merge.Concatenate object at 0xd33cb1f98>
# 309 : pool4_bn, <keras.layers.normalization.BatchNormalization object at 0xd33da90b8>
# 310 : pool4_relu, <keras.layers.core.Activation object at 0xd33d36f60>
# 311 : pool4_conv, <keras.layers.convolutional.Conv2D object at 0xd33dc3a20>
# 312 : pool4_pool, <keras.layers.pooling.AveragePooling2D object at 0xd33dc3d68>
# 313 : conv5_block1_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd33e4b8d0>
# 314 : conv5_block1_0_relu, <keras.layers.core.Activation object at 0xd33f67f98>
# 315 : conv5_block1_1_conv, <keras.layers.convolutional.Conv2D object at 0xd33facb00>
# 316 : conv5_block1_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd33fac898>
# 317 : conv5_block1_1_relu, <keras.layers.core.Activation object at 0xd340142b0>
# 318 : conv5_block1_2_conv, <keras.layers.convolutional.Conv2D object at 0xd3407cf60>
# 319 : conv5_block1_concat, <keras.layers.merge.Concatenate object at 0xd340b9588>
# 320 : conv5_block2_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd3412b908>
# 321 : conv5_block2_0_relu, <keras.layers.core.Activation object at 0xd340fcf98>
# 322 : conv5_block2_1_conv, <keras.layers.convolutional.Conv2D object at 0xd34190ef0>
# 323 : conv5_block2_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd341d0a58>
# 324 : conv5_block2_1_relu, <keras.layers.core.Activation object at 0xd34242908>
# 325 : conv5_block2_2_conv, <keras.layers.convolutional.Conv2D object at 0xd342e9438>
# 326 : conv5_block2_concat, <keras.layers.merge.Concatenate object at 0xd342a5e48>
# 327 : conv5_block3_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd3435b748>
# 328 : conv5_block3_0_relu, <keras.layers.core.Activation object at 0xd34325fd0>
# 329 : conv5_block3_1_conv, <keras.layers.convolutional.Conv2D object at 0xd343befd0>
# 330 : conv5_block3_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd343fc9e8>
# 331 : conv5_block3_1_relu, <keras.layers.core.Activation object at 0xd34472780>
# 332 : conv5_block3_2_conv, <keras.layers.convolutional.Conv2D object at 0xd344d0c18>
# 333 : conv5_block3_concat, <keras.layers.merge.Concatenate object at 0xd344d0d68>
# 334 : conv5_block4_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd345c90f0>
# 335 : conv5_block4_0_relu, <keras.layers.core.Activation object at 0xd34550f98>
# 336 : conv5_block4_1_conv, <keras.layers.convolutional.Conv2D object at 0xd345e6a58>
# 337 : conv5_block4_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd345e6da0>
# 338 : conv5_block4_1_relu, <keras.layers.core.Activation object at 0xd31301400>
# 339 : conv5_block4_2_conv, <keras.layers.convolutional.Conv2D object at 0xd3474be10>
# 340 : conv5_block4_concat, <keras.layers.merge.Concatenate object at 0xd3470db00>
# 341 : conv5_block5_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd347c2390>
# 342 : conv5_block5_0_relu, <keras.layers.core.Activation object at 0xd347976a0>
# 343 : conv5_block5_1_conv, <keras.layers.convolutional.Conv2D object at 0xd3482e828>
# 344 : conv5_block5_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd3482ed30>
# 345 : conv5_block5_1_relu, <keras.layers.core.Activation object at 0xd348d43c8>
# 346 : conv5_block5_2_conv, <keras.layers.convolutional.Conv2D object at 0xd349b6eb8>
# 347 : conv5_block5_concat, <keras.layers.merge.Concatenate object at 0xd34966e48>
# 348 : conv5_block6_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd34a10208>
# 349 : conv5_block6_0_relu, <keras.layers.core.Activation object at 0xd349e0518>
# 350 : conv5_block6_1_conv, <keras.layers.convolutional.Conv2D object at 0xd34a7b6a0>
# 351 : conv5_block6_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd34a7bba8>
# 352 : conv5_block6_1_relu, <keras.layers.core.Activation object at 0xd34b28208>
# 353 : conv5_block6_2_conv, <keras.layers.convolutional.Conv2D object at 0xd34be6d68>
# 354 : conv5_block6_concat, <keras.layers.merge.Concatenate object at 0xd34b91c88>
# 355 : conv5_block7_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd34c401d0>
# 356 : conv5_block7_0_relu, <keras.layers.core.Activation object at 0xd34c0ff28>
# 357 : conv5_block7_1_conv, <keras.layers.convolutional.Conv2D object at 0xd34cfad68>
# 358 : conv5_block7_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd34ca9f98>
# 359 : conv5_block7_1_relu, <keras.layers.core.Activation object at 0xd34d561d0>
# 360 : conv5_block7_2_conv, <keras.layers.convolutional.Conv2D object at 0xd34dbd9e8>
# 361 : conv5_block7_concat, <keras.layers.merge.Concatenate object at 0xd34dbd8d0>
# 362 : conv5_block8_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd34e673c8>
# 363 : conv5_block8_0_relu, <keras.layers.core.Activation object at 0xd34e3ddd8>
# 364 : conv5_block8_1_conv, <keras.layers.convolutional.Conv2D object at 0xd34ed2710>
# 365 : conv5_block8_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd34ed2be0>
# 366 : conv5_block8_1_relu, <keras.layers.core.Activation object at 0xd34f52f60>
# 367 : conv5_block8_2_conv, <keras.layers.convolutional.Conv2D object at 0xd34feb860>
# 368 : conv5_block8_concat, <keras.layers.merge.Concatenate object at 0xd34feb748>
# 369 : conv5_block9_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd3503bf28>
# 370 : conv5_block9_0_relu, <keras.layers.core.Activation object at 0xd350689b0>
# 371 : conv5_block9_1_conv, <keras.layers.convolutional.Conv2D object at 0xd350fc588>
# 372 : conv5_block9_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd350fcc88>
# 373 : conv5_block9_1_relu, <keras.layers.core.Activation object at 0xd35185c50>
# 374 : conv5_block9_2_conv, <keras.layers.convolutional.Conv2D object at 0xd35214630>
# 375 : conv5_block9_concat, <keras.layers.merge.Concatenate object at 0xd35214518>
# 376 : conv5_block10_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd35295278>
# 377 : conv5_block10_0_relu, <keras.layers.core.Activation object at 0xd352fbfd0>
# 378 : conv5_block10_1_conv, <keras.layers.convolutional.Conv2D object at 0xd3533bb70>
# 379 : conv5_block10_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd3533bd30>
# 380 : conv5_block10_1_relu, <keras.layers.core.Activation object at 0xd353ac2b0>
# 381 : conv5_block10_2_conv, <keras.layers.convolutional.Conv2D object at 0xd35412f60>
# 382 : conv5_block10_concat, <keras.layers.merge.Concatenate object at 0xd35450588>
# 383 : conv5_block11_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd354c2908>
# 384 : conv5_block11_0_relu, <keras.layers.core.Activation object at 0xd3548ff98>
# 385 : conv5_block11_1_conv, <keras.layers.convolutional.Conv2D object at 0xd35525ef0>
# 386 : conv5_block11_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd35567a58>
# 387 : conv5_block11_1_relu, <keras.layers.core.Activation object at 0xd355d8908>
# 388 : conv5_block11_2_conv, <keras.layers.convolutional.Conv2D object at 0xd35681438>
# 389 : conv5_block11_concat, <keras.layers.merge.Concatenate object at 0xd3563def0>
# 390 : conv5_block12_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd356f14e0>
# 391 : conv5_block12_0_relu, <keras.layers.core.Activation object at 0xd3569d0f0>
# 392 : conv5_block12_1_conv, <keras.layers.convolutional.Conv2D object at 0xd35752fd0>
# 393 : conv5_block12_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd357d29b0>
# 394 : conv5_block12_1_relu, <keras.layers.core.Activation object at 0xd35845780>
# 395 : conv5_block12_2_conv, <keras.layers.convolutional.Conv2D object at 0xd358a6c18>
# 396 : conv5_block12_concat, <keras.layers.merge.Concatenate object at 0xd358a6d68>
# 397 : conv5_block13_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd359a00f0>
# 398 : conv5_block13_0_relu, <keras.layers.core.Activation object at 0xd35928f98>
# 399 : conv5_block13_1_conv, <keras.layers.convolutional.Conv2D object at 0xd359baa58>
# 400 : conv5_block13_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd359bada0>
# 401 : conv5_block13_1_relu, <keras.layers.core.Activation object at 0xd35a73240>
# 402 : conv5_block13_2_conv, <keras.layers.convolutional.Conv2D object at 0xd35b23e10>
# 403 : conv5_block13_concat, <keras.layers.merge.Concatenate object at 0xd35ad1f60>
# 404 : conv5_block14_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd35b77358>
# 405 : conv5_block14_0_relu, <keras.layers.core.Activation object at 0xd35b4e668>
# 406 : conv5_block14_1_conv, <keras.layers.convolutional.Conv2D object at 0xd35be07f0>
# 407 : conv5_block14_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd35be0cf8>
# 408 : conv5_block14_1_relu, <keras.layers.core.Activation object at 0xd35c86358>
# 409 : conv5_block14_2_conv, <keras.layers.convolutional.Conv2D object at 0xd35d44e10>
# 410 : conv5_block14_concat, <keras.layers.merge.Concatenate object at 0xd35cf3dd8>
# 411 : conv5_block15_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd35da3198>
# 412 : conv5_block15_0_relu, <keras.layers.core.Activation object at 0xd35d6f4a8>
# 413 : conv5_block15_1_conv, <keras.layers.convolutional.Conv2D object at 0xd35e0b630>
# 414 : conv5_block15_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd35e0bb38>
# 415 : conv5_block15_1_relu, <keras.layers.core.Activation object at 0xd35eb91d0>
# 416 : conv5_block15_2_conv, <keras.layers.convolutional.Conv2D object at 0xd35f1db70>
# 417 : conv5_block15_concat, <keras.layers.merge.Concatenate object at 0xd35f1da58>
# 418 : conv5_block16_0_bn, <keras.layers.normalization.BatchNormalization object at 0xd35fca198>
# 419 : conv5_block16_0_relu, <keras.layers.core.Activation object at 0xd35f97dd8>
# 420 : conv5_block16_1_conv, <keras.layers.convolutional.Conv2D object at 0xd360339b0>
# 421 : conv5_block16_1_bn, <keras.layers.normalization.BatchNormalization object at 0xd36033898>
# 422 : conv5_block16_1_relu, <keras.layers.core.Activation object at 0xd360b6f60>
# 423 : conv5_block16_2_conv, <keras.layers.convolutional.Conv2D object at 0xd3614c940>
# 424 : conv5_block16_concat, <keras.layers.merge.Concatenate object at 0xd3614c828>
# 425 : bn, <keras.layers.normalization.BatchNormalization object at 0xd361f42b0>
# 426 : avg_pool, <keras.layers.pooling.GlobalAveragePooling2D object at 0xd361c9668>
# 427 : fc1000, <keras.layers.core.Dense object at 0xd36261cf8>
# 428 : fc1000__activation__, <keras.layers.core.Activation object at 0xd3a4e4b38>

# %% [markdown]
# ### Save the model as a .mlmodel file which can be deployed

# %%
mlmodel.save('ModelZoo/DenseNet121.mlmodel')

# %% [markdown]
# ### Now extract the model using the TensorFlow session to convert it for Android

# %%
S = K.get_session()
constant_graph = graph_util.convert_variables_to_constants(S, 
                                                           S.graph.as_graph_def(),
                                                           ['fc1000/Softmax'])
graph_io.write_graph(constant_graph, 'ModelZoo/', 'DenseNet121.pb', as_text=False)
# Out:
# INFO:tensorflow:Froze 606 variables.
# INFO:tensorflow:Froze 606 variables.
# INFO:tensorflow:Converted 606 variables to const ops.
# INFO:tensorflow:Converted 606 variables to const ops.
# 'ModelZoo/DenseNet121.pb'

# %% [markdown]
# ### To convert the model for TensorFlow Lite

# %%
# To convert the model for tensorflow lite, we can save the keras model
# and then convert it into a TensorFlow lite model directly

input_tensor = tf.keras.layers.Input(shape=(224,224,3))
model = tf.keras.applications.densenet.DenseNet121(
    weights='imagenet', input_tensor=input_tensor, include_top=True
)

keras_file = 'ModelZoo/DenseNet121.h5'
tf.keras.models.save_model(model, keras_file)

converter = tf.contrib.lite.TFLiteConverter.from_keras_model_file(keras_file)
tflite_model = converter.convert()
open('ModelZoo/'+'DenseNet121.tflite', 'wb').write(tflite_model)
# Out:
# A local file was found, but it seems to be incomplete or outdated because the auto file hash does not match the original value of 9d60b8095a5708f2dcce2bca79d332c7 so we will re-download the data.
# Downloading data from https://github.com/keras-team/keras-applications/releases/download/densenet/densenet121_weights_tf_dim_ordering_tf_kernels.h5
# 33193984/33188688 [==============================] - 2s 0us/step

# %% [markdown]
# ### Now load the model and get the details of the converted model
# ### These are useful when deploying the models on Android

# %%
interpreter = tf.contrib.lite.Interpreter(model_path='ModelZoo/DenseNet121.tflite')

interpreter.allocate_tensors()

input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()
print(input_details, output_details)
